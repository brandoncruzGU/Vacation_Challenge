# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 756

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})    
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 1 | kolimvari
# City not found. Skipping...
# Processing Record 3 of Set 1 | pinar del rio
# Processing Record 4 of Set 1 | santiago del estero
# Processing Record 5 of Set 1 | felanitx
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 8 of Set 1 | bealanana
# Processing Record 9 of Set 1 | warrington
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | milas
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 1 | santa cruz de la palma
# Processing Record 15 of Set 1 | ayagoz
# Processing Record 16 of Set 1 | macau
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | victoria
# Processing Record 19 of Set 1 | bengkulu
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | narsaq
# Processing Record 22 of Set 1 | male
# Processing Record 23 of Set 1 | sorland
# Processing Record 24 of Set 1 | hithadhoo
# Processing Record 25 of Set 1 | ondjiva
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 1 | sao joao da barra
# Processing Record 29 of Set 1 | the valley
# Processing Record 30 of Set 1 | navalmoral de la mata
# Processing Record 31 of Set 1 | adrar
# Processing Record 32 of Set 1 | omboue
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | tutoia
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | mehamn
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | ostrovnoy
# Processing Record 39 of Set 1 | tasiilaq
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | khash
# Processing Record 42 of Set 1 | peniche
# Processing Record 43 of Set 1 | bilma
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 1 | puquio
# Processing Record 47 of Set 1 | miravci
# Processing Record 48 of Set 1 | kachiry
# Processing Record 49 of Set 1 | margate
# Processing Record 50 of Set 1 | georgetown
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 2 | tall kayf
# Processing Record 5 of Set 2 | marfino
# Processing Record 6 of Set 2 | hamilton
# Processing Record 7 of Set 2 | luderitz
# Processing Record 8 of Set 2 | quiindy
# Processing Record 9 of Set 2 | khandbari
# Processing Record 10 of Set 2 | vestmannaeyjar
# Processing Record 11 of Set 2 | duz
# City not found. Skipping...
# Processing Record 12 of Set 2 | san cristobal
# Processing Record 13 of Set 2 | bata
# Processing Record 14 of Set 2 | arlit
# Processing Record 15 of Set 2 | laguna
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | marrakesh
# Processing Record 18 of Set 2 | narasimharajapura
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | of
# City not found. Skipping...
# Processing Record 21 of Set 2 | mahibadhoo
# Processing Record 22 of Set 2 | sambava
# Processing Record 23 of Set 2 | tarko-sale
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | bandarbeyla
# Processing Record 27 of Set 2 | rabo de peixe
# Processing Record 28 of Set 2 | iracoubo
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | morro agudo
# Processing Record 31 of Set 2 | panguipulli
# Processing Record 32 of Set 2 | norwalk
# Processing Record 33 of Set 2 | cayenne
# Processing Record 34 of Set 2 | santa marta
# Processing Record 35 of Set 2 | marsh harbour
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | tabou
# Processing Record 38 of Set 2 | ketovo
# Processing Record 39 of Set 2 | salalah
# Processing Record 40 of Set 2 | muros
# Processing Record 41 of Set 2 | roald
# Processing Record 42 of Set 2 | skelleftea
# Processing Record 43 of Set 2 | codrington
# Processing Record 44 of Set 2 | bathsheba
# Processing Record 45 of Set 2 | brae
# Processing Record 46 of Set 2 | necochea
# Processing Record 47 of Set 2 | chapadinha
# Processing Record 48 of Set 2 | santa vitoria do palmar
# Processing Record 49 of Set 2 | bambous virieux
# Processing Record 50 of Set 2 | torquay
# Processing Record 1 of Set 3 | honningsvag
# Processing Record 2 of Set 3 | corinto
# Processing Record 3 of Set 3 | olinda
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | longyearbyen
# Processing Record 6 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 3 | hofn
# Processing Record 9 of Set 3 | upernavik
# Processing Record 10 of Set 3 | nizhniy baskunchak
# Processing Record 11 of Set 3 | proletarskiy
# Processing Record 12 of Set 3 | paola
# Processing Record 13 of Set 3 | ribeira grande
# Processing Record 14 of Set 3 | qaqortoq
# Processing Record 15 of Set 3 | mattru
# Processing Record 16 of Set 3 | bonthe
# Processing Record 17 of Set 3 | olinthos
# City not found. Skipping...
# Processing Record 18 of Set 3 | nanortalik
# Processing Record 19 of Set 3 | clyde river
# Processing Record 20 of Set 3 | gamba
# Processing Record 21 of Set 3 | upata
# Processing Record 22 of Set 3 | santo antonio do monte
# Processing Record 23 of Set 3 | cidreira
# Processing Record 24 of Set 3 | bonavista
# Processing Record 25 of Set 3 | jawhar
# Processing Record 26 of Set 3 | mogadishu
# Processing Record 27 of Set 3 | boende
# Processing Record 28 of Set 3 | corozal
# Processing Record 29 of Set 3 | huarmey
# Processing Record 30 of Set 3 | ust-kalmanka
# Processing Record 31 of Set 3 | bafq
# Processing Record 32 of Set 3 | torbay
# Processing Record 33 of Set 3 | anloga
# Processing Record 34 of Set 3 | campbeltown
# Processing Record 35 of Set 3 | berlevag
# Processing Record 36 of Set 3 | paipa
# Processing Record 37 of Set 3 | lwowek slaski
# Processing Record 38 of Set 3 | namibe
# Processing Record 39 of Set 3 | elizabeth city
# Processing Record 40 of Set 3 | tromso
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | casablanca
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | camacha
# Processing Record 45 of Set 3 | qarqin
# Processing Record 46 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 47 of Set 3 | tucuman
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | manoel urbano
# Processing Record 50 of Set 3 | bosobolo
# Processing Record 1 of Set 4 | ponta do sol
# Processing Record 2 of Set 4 | hambantota
# Processing Record 3 of Set 4 | leshukonskoye
# Processing Record 4 of Set 4 | henties bay
# Processing Record 5 of Set 4 | garowe
# Processing Record 6 of Set 4 | guarapari
# Processing Record 7 of Set 4 | tefe
# Processing Record 8 of Set 4 | baft
# Processing Record 9 of Set 4 | storforshei
# Processing Record 10 of Set 4 | puerto carreno
# Processing Record 11 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 12 of Set 4 | ochakiv
# Processing Record 13 of Set 4 | pizarro
# Processing Record 14 of Set 4 | mugur-aksy
# Processing Record 15 of Set 4 | proddatur
# Processing Record 16 of Set 4 | pauini
# Processing Record 17 of Set 4 | chapais
# Processing Record 18 of Set 4 | stornoway
# Processing Record 19 of Set 4 | kudahuvadhoo
# Processing Record 20 of Set 4 | lebu
# Processing Record 21 of Set 4 | troitsko-pechorsk
# Processing Record 22 of Set 4 | raudeberg
# Processing Record 23 of Set 4 | naifaru
# Processing Record 24 of Set 4 | gashua
# Processing Record 25 of Set 4 | mabaruma
# Processing Record 26 of Set 4 | tibu
# Processing Record 27 of Set 4 | cockburn town
# Processing Record 28 of Set 4 | tiznit
# Processing Record 29 of Set 4 | husavik
# Processing Record 30 of Set 4 | maykain
# City not found. Skipping...
# Processing Record 31 of Set 4 | mbini
# Processing Record 32 of Set 4 | souillac
# Processing Record 33 of Set 4 | oistins
# Processing Record 34 of Set 4 | wajir
# Processing Record 35 of Set 4 | zilupe
# Processing Record 36 of Set 4 | trofors
# Processing Record 37 of Set 4 | urucara
# Processing Record 38 of Set 4 | muisne
# Processing Record 39 of Set 4 | diego de almagro
# Processing Record 40 of Set 4 | yining
# Processing Record 41 of Set 4 | quatre cocos
# Processing Record 42 of Set 4 | ancud
# Processing Record 43 of Set 4 | plopsoru
# Processing Record 44 of Set 4 | vila velha
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | bilecik
# Processing Record 47 of Set 4 | coquimbo
# Processing Record 48 of Set 4 | touros
# Processing Record 49 of Set 4 | coruripe
# Processing Record 50 of Set 4 | wattegama
# Processing Record 1 of Set 5 | porto novo
# Processing Record 2 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 3 of Set 5 | qesarya
# Processing Record 4 of Set 5 | scarborough
# Processing Record 5 of Set 5 | linhares
# Processing Record 6 of Set 5 | nueva gerona
# Processing Record 7 of Set 5 | hammerfest
# Processing Record 8 of Set 5 | manta
# Processing Record 9 of Set 5 | vila franca do campo
# Processing Record 10 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 5 | coihaique
# Processing Record 12 of Set 5 | gilgit
# Processing Record 13 of Set 5 | mokshan
# Processing Record 14 of Set 5 | la palma
# Processing Record 15 of Set 5 | jamnah
# City not found. Skipping...
# Processing Record 16 of Set 5 | bajil
# Processing Record 17 of Set 5 | repalle
# Processing Record 18 of Set 5 | kita
# Processing Record 19 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 20 of Set 5 | malini
# Processing Record 21 of Set 5 | oum hadjer
# Processing Record 22 of Set 5 | celina
# Processing Record 23 of Set 5 | mamallapuram
# Processing Record 24 of Set 5 | gurupi
# Processing Record 25 of Set 5 | aswan
# Processing Record 26 of Set 5 | lahij
# Processing Record 27 of Set 5 | capitan bado
# Processing Record 28 of Set 5 | falun
# Processing Record 29 of Set 5 | san andres
# Processing Record 30 of Set 5 | tupiza
# Processing Record 31 of Set 5 | bezhetsk
# Processing Record 32 of Set 5 | toamasina
# Processing Record 33 of Set 5 | inhambane
# Processing Record 34 of Set 5 | praia da vitoria
# Processing Record 35 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 5 | imbituba
# Processing Record 37 of Set 5 | lasa
# Processing Record 38 of Set 5 | loubomo
# Processing Record 39 of Set 5 | bredasdorp
# Processing Record 40 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 41 of Set 5 | mufumbwe
# Processing Record 42 of Set 5 | mwinilunga
# Processing Record 43 of Set 5 | rum
# Processing Record 44 of Set 5 | sinnamary
# Processing Record 45 of Set 5 | muhos
# Processing Record 46 of Set 5 | nizwa
# Processing Record 47 of Set 5 | naryan-mar
# Processing Record 48 of Set 5 | cayeli
# Processing Record 49 of Set 5 | san rafael del sur
# Processing Record 50 of Set 5 | bumba
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | karaton
# Processing Record 3 of Set 6 | yeroham
# Processing Record 4 of Set 6 | carnarvon
# Processing Record 5 of Set 6 | ponta delgada
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | seica mica
# Processing Record 8 of Set 6 | quelimane
# Processing Record 9 of Set 6 | takoradi
# Processing Record 10 of Set 6 | cascavel
# Processing Record 11 of Set 6 | sulecin
# Processing Record 12 of Set 6 | unye
# City not found. Skipping...
# Processing Record 13 of Set 6 | semypolky
# Processing Record 14 of Set 6 | pangnirtung
# Processing Record 15 of Set 6 | mehran
# Processing Record 16 of Set 6 | jalu
# Processing Record 17 of Set 6 | humaita
# Processing Record 18 of Set 6 | lagoa
# Processing Record 19 of Set 6 | buraydah
# Processing Record 20 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 6 | sinazongwe
# Processing Record 22 of Set 6 | vastervik
# City not found. Skipping...
# Processing Record 23 of Set 6 | rio grande
# Processing Record 24 of Set 6 | saint anthony
# Processing Record 25 of Set 6 | sistranda
# Processing Record 26 of Set 6 | verkhnyaya inta
# Processing Record 27 of Set 6 | tahoua
# Processing Record 28 of Set 6 | dunn
# Processing Record 29 of Set 6 | itacoatiara
# Processing Record 30 of Set 6 | hit
# Processing Record 31 of Set 6 | bull savanna
# Processing Record 32 of Set 6 | socota
# Processing Record 33 of Set 6 | cuenca
# Processing Record 34 of Set 6 | bam
# Processing Record 35 of Set 6 | botngard
# Processing Record 36 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 38 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 39 of Set 6 | ndago
# Processing Record 40 of Set 6 | olafsvik
# Processing Record 41 of Set 6 | gat
# Processing Record 42 of Set 6 | ambilobe
# Processing Record 43 of Set 6 | muyezerskiy
# Processing Record 44 of Set 6 | guarenas
# Processing Record 45 of Set 6 | kabwe
# Processing Record 46 of Set 6 | lieksa
# Processing Record 47 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 6 | kentau
# Processing Record 49 of Set 6 | axim
# Processing Record 50 of Set 6 | sabathu
# Processing Record 1 of Set 7 | islamkot
# Processing Record 2 of Set 7 | brokopondo
# Processing Record 3 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 4 of Set 7 | borujerd
# Processing Record 5 of Set 7 | akdepe
# Processing Record 6 of Set 7 | inongo
# Processing Record 7 of Set 7 | ibra
# Processing Record 8 of Set 7 | lefka
# Processing Record 9 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 10 of Set 7 | camana
# Processing Record 11 of Set 7 | santiago de cao
# Processing Record 12 of Set 7 | belmopan
# Processing Record 13 of Set 7 | sucua
# Processing Record 14 of Set 7 | los llanos de aridane
# Processing Record 15 of Set 7 | kruisfontein
# Processing Record 16 of Set 7 | alvaraes
# Processing Record 17 of Set 7 | cabedelo
# Processing Record 18 of Set 7 | pemba
# Processing Record 19 of Set 7 | suez
# Processing Record 20 of Set 7 | parana
# Processing Record 21 of Set 7 | korla
# Processing Record 22 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 7 | toulepleu
# City not found. Skipping...
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | zatoka
# Processing Record 26 of Set 7 | klobuck
# Processing Record 27 of Set 7 | prilep
# Processing Record 28 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 7 | hobyo
# Processing Record 30 of Set 7 | road town
# Processing Record 31 of Set 7 | mumford
# Processing Record 32 of Set 7 | presidencia roque saenz pena
# Processing Record 33 of Set 7 | kamareddi
# Processing Record 34 of Set 7 | thinadhoo
# Processing Record 35 of Set 7 | luena
# Processing Record 36 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 37 of Set 7 | dudinka
# Processing Record 38 of Set 7 | rocha
# Processing Record 39 of Set 7 | eyl
# Processing Record 40 of Set 7 | severnyy
# Processing Record 41 of Set 7 | bayji
# Processing Record 42 of Set 7 | sao jose da coroa grande
# Processing Record 43 of Set 7 | general pico
# Processing Record 44 of Set 7 | beloha
# Processing Record 45 of Set 7 | kyshtovka
# Processing Record 46 of Set 7 | safaga
# Processing Record 47 of Set 7 | grong
# Processing Record 48 of Set 7 | nuuk
# Processing Record 49 of Set 7 | sahrak
# City not found. Skipping...
# Processing Record 50 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 8 | matagami
# Processing Record 2 of Set 8 | karera
# Processing Record 3 of Set 8 | faya
# Processing Record 4 of Set 8 | itaituba
# Processing Record 5 of Set 8 | mount darwin
# Processing Record 6 of Set 8 | opuwo
# Processing Record 7 of Set 8 | oxelosund
# Processing Record 8 of Set 8 | qarayeri
# Processing Record 9 of Set 8 | inirida
# Processing Record 10 of Set 8 | usinsk
# Processing Record 11 of Set 8 | kvam
# Processing Record 12 of Set 8 | jaru
# Processing Record 13 of Set 8 | mitsamiouli
# Processing Record 14 of Set 8 | blagoveshchenka
# Processing Record 15 of Set 8 | primorsk
# Processing Record 16 of Set 8 | diffa
# Processing Record 17 of Set 8 | otukpo
# Processing Record 18 of Set 8 | mayumba
# Processing Record 19 of Set 8 | rostaq
# City not found. Skipping...
# Processing Record 20 of Set 8 | viedma
# Processing Record 21 of Set 8 | havre-saint-pierre
# Processing Record 22 of Set 8 | kargopol
# Processing Record 23 of Set 8 | sao felix do xingu
# Processing Record 24 of Set 8 | grindavik
# Processing Record 25 of Set 8 | tripoli
# Processing Record 26 of Set 8 | kiruna
# Processing Record 27 of Set 8 | karpogory
# Processing Record 28 of Set 8 | eirunepe
# Processing Record 29 of Set 8 | sept-iles
# Processing Record 30 of Set 8 | west lafayette
# Processing Record 31 of Set 8 | teguldet
# Processing Record 32 of Set 8 | mwanza
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | mananjary
# Processing Record 35 of Set 8 | san carlos de bariloche
# Processing Record 36 of Set 8 | rudbar
# Processing Record 37 of Set 8 | san ramon
# Processing Record 38 of Set 8 | paamiut
# Processing Record 39 of Set 8 | vage
# Processing Record 40 of Set 8 | odienne
# Processing Record 41 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 8 | sadri
# Processing Record 43 of Set 8 | athy
# Processing Record 44 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 8 | comodoro rivadavia
# Processing Record 46 of Set 8 | shemonaikha
# Processing Record 47 of Set 8 | bhalwal
# Processing Record 48 of Set 8 | nivala
# Processing Record 49 of Set 8 | semnan
# Processing Record 50 of Set 8 | orcotuna
# Processing Record 1 of Set 9 | pozo colorado
# Processing Record 2 of Set 9 | yugo-kamskiy
# Processing Record 3 of Set 9 | tahta
# Processing Record 4 of Set 9 | ugoofaaru
# Processing Record 5 of Set 9 | el mahalla el kubra
# City not found. Skipping...
# Processing Record 6 of Set 9 | magaria
# Processing Record 7 of Set 9 | igarka
# Processing Record 8 of Set 9 | pichayevo
# Processing Record 9 of Set 9 | tombouctou
# Processing Record 10 of Set 9 | ilula
# Processing Record 11 of Set 9 | monroe
# Processing Record 12 of Set 9 | baymak
# Processing Record 13 of Set 9 | rypefjord
# Processing Record 14 of Set 9 | puerto baquerizo moreno
# Processing Record 15 of Set 9 | dingle
# Processing Record 16 of Set 9 | san jose
# Processing Record 17 of Set 9 | tirumullaivasal
# Processing Record 18 of Set 9 | port-cartier
# Processing Record 19 of Set 9 | kamina
# Processing Record 20 of Set 9 | havelock
# Processing Record 21 of Set 9 | emba
# Processing Record 22 of Set 9 | sohag
# Processing Record 23 of Set 9 | boyabat
# Processing Record 24 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 25 of Set 9 | maniitsoq
# Processing Record 26 of Set 9 | halifax
# Processing Record 27 of Set 9 | malatya
# Processing Record 28 of Set 9 | iquique
# Processing Record 29 of Set 9 | chipinge
# Processing Record 30 of Set 9 | oranjestad
# Processing Record 31 of Set 9 | menongue
# Processing Record 32 of Set 9 | anandnagar
# Processing Record 33 of Set 9 | zabol
# Processing Record 34 of Set 9 | pocinhos
# Processing Record 35 of Set 9 | grand gaube
# Processing Record 36 of Set 9 | saint-pierre
# Processing Record 37 of Set 9 | montgomery
# Processing Record 38 of Set 9 | douentza
# Processing Record 39 of Set 9 | camocim
# Processing Record 40 of Set 9 | saint-ambroise
# Processing Record 41 of Set 9 | develi
# Processing Record 42 of Set 9 | salaverry
# Processing Record 43 of Set 9 | bhimunipatnam
# Processing Record 44 of Set 9 | deer lake
# Processing Record 45 of Set 9 | rosita
# Processing Record 46 of Set 9 | vuktyl
# Processing Record 47 of Set 9 | sao filipe
# Processing Record 48 of Set 9 | port blair
# Processing Record 49 of Set 9 | svetlogorsk
# Processing Record 50 of Set 9 | xuddur
# Processing Record 1 of Set 10 | kourou
# Processing Record 2 of Set 10 | bubaque
# Processing Record 3 of Set 10 | tabas
# Processing Record 4 of Set 10 | kuytun
# Processing Record 5 of Set 10 | los palacios
# Processing Record 6 of Set 10 | saint-claude
# Processing Record 7 of Set 10 | salym
# Processing Record 8 of Set 10 | veraval
# Processing Record 9 of Set 10 | geraldton
# Processing Record 10 of Set 10 | rundu
# Processing Record 11 of Set 10 | pitimbu
# Processing Record 12 of Set 10 | el paso
# Processing Record 13 of Set 10 | altay
# Processing Record 14 of Set 10 | dale
# Processing Record 15 of Set 10 | shupiyan
# Processing Record 16 of Set 10 | valparaiso
# Processing Record 17 of Set 10 | lere
# Processing Record 18 of Set 10 | estelle
# Processing Record 19 of Set 10 | havoysund
# Processing Record 20 of Set 10 | carutapera
# Processing Record 21 of Set 10 | lyuban
# Processing Record 22 of Set 10 | ramsgate
# Processing Record 23 of Set 10 | moose factory
# Processing Record 24 of Set 10 | novoaleksandrovsk
# Processing Record 25 of Set 10 | carbonia
# Processing Record 26 of Set 10 | klaksvik
# Processing Record 27 of Set 10 | surgut
# Processing Record 28 of Set 10 | channel-port aux basques
# Processing Record 29 of Set 10 | alcantara
# Processing Record 30 of Set 10 | staryy nadym
# Processing Record 31 of Set 10 | aksu
# Processing Record 32 of Set 10 | iki-burul
# Processing Record 33 of Set 10 | beisfjord
# Processing Record 34 of Set 10 | barranco
# Processing Record 35 of Set 10 | umm lajj
# Processing Record 36 of Set 10 | natal
# Processing Record 37 of Set 10 | hamirpur
# Processing Record 38 of Set 10 | novovasylivka
# Processing Record 39 of Set 10 | andenes
# Processing Record 40 of Set 10 | strezhevoy
# Processing Record 41 of Set 10 | partanna
# Processing Record 42 of Set 10 | taltal
# Processing Record 43 of Set 10 | angoche
# Processing Record 44 of Set 10 | sarwar
# Processing Record 45 of Set 10 | maine-soroa
# Processing Record 46 of Set 10 | durazno
# Processing Record 47 of Set 10 | sar-e pul
# Processing Record 48 of Set 10 | koslan
# Processing Record 49 of Set 10 | bandipur
# Processing Record 50 of Set 10 | sabaudia
# Processing Record 1 of Set 11 | trairi
# Processing Record 2 of Set 11 | pinega
# Processing Record 3 of Set 11 | constitucion
# Processing Record 4 of Set 11 | belem de sao francisco
# Processing Record 5 of Set 11 | caravelas
# Processing Record 6 of Set 11 | amontada
# Processing Record 7 of Set 11 | osmanabad
# Processing Record 8 of Set 11 | melo
# Processing Record 9 of Set 11 | novyy urengoy
# Processing Record 10 of Set 11 | gloversville
# Processing Record 11 of Set 11 | birjand
# Processing Record 12 of Set 11 | velikie luki
# City not found. Skipping...
# Processing Record 13 of Set 11 | barcelona
# Processing Record 14 of Set 11 | rorvik
# Processing Record 15 of Set 11 | doha
# Processing Record 16 of Set 11 | gastonia
# Processing Record 17 of Set 11 | alpena
# Processing Record 18 of Set 11 | asayita
# City not found. Skipping...
# Processing Record 19 of Set 11 | liverpool
# Processing Record 20 of Set 11 | richards bay
# Processing Record 21 of Set 11 | cabinda
# Processing Record 22 of Set 11 | gunjur
# Processing Record 23 of Set 11 | burriana
# Processing Record 24 of Set 11 | talnakh
# Processing Record 25 of Set 11 | abu kamal
# Processing Record 26 of Set 11 | la union
# Processing Record 27 of Set 11 | novi sanzhary
# Processing Record 28 of Set 11 | naregal
# Processing Record 29 of Set 11 | antalaha
# Processing Record 30 of Set 11 | kochubey
# Processing Record 31 of Set 11 | general roca
# Processing Record 32 of Set 11 | filadelfia
# Processing Record 33 of Set 11 | mayor pablo lagerenza
# Processing Record 34 of Set 11 | jammalamadugu
# Processing Record 35 of Set 11 | anori
# Processing Record 36 of Set 11 | nikolsk
# Processing Record 37 of Set 11 | addi ugri
# City not found. Skipping...
# Processing Record 38 of Set 11 | ust-tsilma
# Processing Record 39 of Set 11 | chimbote
# Processing Record 40 of Set 11 | raga
# Processing Record 41 of Set 11 | harper
# Processing Record 42 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 43 of Set 11 | englewood
# Processing Record 44 of Set 11 | altamira
# Processing Record 45 of Set 11 | salinopolis
# Processing Record 46 of Set 11 | plouzane
# Processing Record 47 of Set 11 | uruzgan
# Processing Record 48 of Set 11 | nantucket
# Processing Record 49 of Set 11 | teodoro sampaio
# Processing Record 50 of Set 11 | tete
# Processing Record 1 of Set 12 | roanoke rapids
# Processing Record 2 of Set 12 | trojes
# Processing Record 3 of Set 12 | algete
# Processing Record 4 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 12 | paita
# Processing Record 6 of Set 12 | lobito
# Processing Record 7 of Set 12 | sondrio
# Processing Record 8 of Set 12 | xambioa
# Processing Record 9 of Set 12 | dromolaxia
# Processing Record 10 of Set 12 | saint-joseph
# Processing Record 11 of Set 12 | digha
# Processing Record 12 of Set 12 | maceio
# Processing Record 13 of Set 12 | isiolo
# Processing Record 14 of Set 12 | mbandaka
# Processing Record 15 of Set 12 | karpathos
# Processing Record 16 of Set 12 | beyneu
# Processing Record 17 of Set 12 | regeneracao
# Processing Record 18 of Set 12 | bulnes
# Processing Record 19 of Set 12 | tessalit
# Processing Record 20 of Set 12 | kedrovyy
# Processing Record 21 of Set 12 | kibondo
# Processing Record 22 of Set 12 | sokoni
# Processing Record 23 of Set 12 | pitlochry
# Processing Record 24 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 25 of Set 12 | kamenka
# Processing Record 26 of Set 12 | great yarmouth
# Processing Record 27 of Set 12 | tandil
# Processing Record 28 of Set 12 | rawson
# Processing Record 29 of Set 12 | utiel
# Processing Record 30 of Set 12 | barabinsk
# Processing Record 31 of Set 12 | mathbaria
# Processing Record 32 of Set 12 | aras
# Processing Record 33 of Set 12 | kjollefjord
# Processing Record 34 of Set 12 | alakurtti
# Processing Record 35 of Set 12 | maxixe
# Processing Record 36 of Set 12 | saurimo
# Processing Record 37 of Set 12 | shache
# Processing Record 38 of Set 12 | shelburne
# Processing Record 39 of Set 12 | yabrud
# Processing Record 40 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 12 | quibor
# Processing Record 42 of Set 12 | lagunas
# Processing Record 43 of Set 12 | abda
# Processing Record 44 of Set 12 | wanderlandia
# City not found. Skipping...
# Processing Record 45 of Set 12 | bridlington
# Processing Record 46 of Set 12 | rasulnagar
# Processing Record 47 of Set 12 | wamba
# Processing Record 48 of Set 12 | mansa
# Processing Record 49 of Set 12 | poykovskiy
# Processing Record 50 of Set 12 | shush
# Processing Record 1 of Set 13 | saint-georges
# Processing Record 2 of Set 13 | plettenberg bay
# Processing Record 3 of Set 13 | boo
# Processing Record 4 of Set 13 | taoudenni
# Processing Record 5 of Set 13 | stulovo
# Processing Record 6 of Set 13 | barra do garcas
# Processing Record 7 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 8 of Set 13 | yenagoa
# Processing Record 9 of Set 13 | sasovo
# Processing Record 10 of Set 13 | mega
# Processing Record 11 of Set 13 | thamaga
# Processing Record 12 of Set 13 | conway
# Processing Record 13 of Set 13 | bogande
# Processing Record 14 of Set 13 | umkomaas
# Processing Record 15 of Set 13 | baghmara
# Processing Record 16 of Set 13 | zhanaozen
# Processing Record 17 of Set 13 | kyzyl-suu
# Processing Record 18 of Set 13 | candolim
# Processing Record 19 of Set 13 | dolores
# Processing Record 20 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 21 of Set 13 | acarau
# Processing Record 22 of Set 13 | westport
# Processing Record 23 of Set 13 | owando
# Processing Record 24 of Set 13 | bud
# Processing Record 25 of Set 13 | bonfim
# Processing Record 26 of Set 13 | leh
# Processing Record 27 of Set 13 | barra patuca
# Processing Record 28 of Set 13 | kuju
# Processing Record 29 of Set 13 | springbok
# Processing Record 30 of Set 13 | lulea
# Processing Record 31 of Set 13 | cururupu
# Processing Record 32 of Set 13 | srivardhan
# Processing Record 33 of Set 13 | inca
# Processing Record 34 of Set 13 | campo grande
# Processing Record 35 of Set 13 | los aquijes
# Processing Record 36 of Set 13 | ambovombe
# Processing Record 37 of Set 13 | chincha alta
# Processing Record 38 of Set 13 | puerto madryn
# Processing Record 39 of Set 13 | wageningen
# Processing Record 40 of Set 13 | aguilas
# Processing Record 41 of Set 13 | vengerovo
# Processing Record 42 of Set 13 | nicoya
# Processing Record 43 of Set 13 | kulu
# Processing Record 44 of Set 13 | azul
# Processing Record 45 of Set 13 | kashi
# Processing Record 46 of Set 13 | zheshart
# Processing Record 47 of Set 13 | beira
# Processing Record 48 of Set 13 | ivanovskoye
# Processing Record 49 of Set 13 | valverde del camino
# Processing Record 50 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 1 of Set 14 | lamu
# Processing Record 2 of Set 14 | zelenoborsk
# Processing Record 3 of Set 14 | khowst
# Processing Record 4 of Set 14 | banyo
# Processing Record 5 of Set 14 | jacareacanga
# Processing Record 6 of Set 14 | kazanskaya
# Processing Record 7 of Set 14 | niesky
# Processing Record 8 of Set 14 | coari
# Processing Record 9 of Set 14 | boras
# Processing Record 10 of Set 14 | awjilah
# Processing Record 11 of Set 14 | sheltozero
# Processing Record 12 of Set 14 | labrea
# Processing Record 13 of Set 14 | belyy yar
# Processing Record 14 of Set 14 | pilao arcado
# City not found. Skipping...
# Processing Record 15 of Set 14 | atar
# Processing Record 16 of Set 14 | ballina
# Processing Record 17 of Set 14 | ballinrobe
# Processing Record 18 of Set 14 | garmsar
# Processing Record 19 of Set 14 | belmonte
# Processing Record 20 of Set 14 | kidal
# Processing Record 21 of Set 14 | tashtagol
# Processing Record 22 of Set 14 | poco das trincheiras
# Processing Record 23 of Set 14 | dmitriyevka
# Processing Record 24 of Set 14 | buzmeyin
# Processing Record 25 of Set 14 | lusambo
# Processing Record 26 of Set 14 | aleksandrov gay
# Processing Record 27 of Set 14 | eenhana
# Processing Record 28 of Set 14 | safranbolu
# Processing Record 29 of Set 14 | caxito
# Processing Record 30 of Set 14 | aquiraz
# Processing Record 31 of Set 14 | kushmurun
# Processing Record 32 of Set 14 | mulchen
# Processing Record 33 of Set 14 | dehri
# Processing Record 34 of Set 14 | timberlake
# Processing Record 35 of Set 14 | praia
# Processing Record 36 of Set 14 | kuito
# Processing Record 37 of Set 14 | cave spring
# Processing Record 38 of Set 14 | bara
# Processing Record 39 of Set 14 | grand-lahou
# Processing Record 40 of Set 14 | san rafael
# Processing Record 41 of Set 14 | le vauclin
# Processing Record 42 of Set 14 | jurado
# Processing Record 43 of Set 14 | pittsfield
# Processing Record 44 of Set 14 | dzaoudzi
# Processing Record 45 of Set 14 | kurchum
# Processing Record 46 of Set 14 | mahanoro
# Processing Record 47 of Set 14 | loukhi
# Processing Record 48 of Set 14 | kalemie
# Processing Record 49 of Set 14 | nola
# Processing Record 50 of Set 14 | chachapoyas
# Processing Record 1 of Set 15 | iqaluit
# Processing Record 2 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 15 | royal tunbridge wells
# Processing Record 4 of Set 15 | gander
# Processing Record 5 of Set 15 | brandon
# Processing Record 6 of Set 15 | santa maria
# Processing Record 7 of Set 15 | cancun
# Processing Record 8 of Set 15 | labe
# Processing Record 9 of Set 15 | ubinskoye
# Processing Record 10 of Set 15 | chabahar
# Processing Record 11 of Set 15 | marawi
# Processing Record 12 of Set 15 | kendal
# Processing Record 13 of Set 15 | loiza
# Processing Record 14 of Set 15 | ouro preto do oeste
# Processing Record 15 of Set 15 | ati
# Processing Record 16 of Set 15 | agaro
# Processing Record 17 of Set 15 | yangambi
# Processing Record 18 of Set 15 | gambela
# Processing Record 19 of Set 15 | yar-sale
# Processing Record 20 of Set 15 | baherden
# Processing Record 21 of Set 15 | kathmandu
# Processing Record 22 of Set 15 | amarante do maranhao
# Processing Record 23 of Set 15 | tabuk
# Processing Record 24 of Set 15 | ilhabela
# Processing Record 25 of Set 15 | chicama
# Processing Record 26 of Set 15 | turukhansk
# Processing Record 27 of Set 15 | kingston
# Processing Record 28 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 15 | najran
# Processing Record 30 of Set 15 | shubarkuduk
# Processing Record 31 of Set 15 | la asuncion
# Processing Record 32 of Set 15 | botad
# Processing Record 33 of Set 15 | port-gentil
# Processing Record 34 of Set 15 | lavumisa
# Processing Record 35 of Set 15 | les cayes
# Processing Record 36 of Set 15 | conceicao do araguaia
# Processing Record 37 of Set 15 | kutum
# Processing Record 38 of Set 15 | markala
# Processing Record 39 of Set 15 | sao gabriel da cachoeira
# Processing Record 40 of Set 15 | dhidhdhoo
# Processing Record 41 of Set 15 | livingstonia
# Processing Record 42 of Set 15 | itarema
# Processing Record 43 of Set 15 | meulaboh
# Processing Record 44 of Set 15 | puerto del rosario
# Processing Record 45 of Set 15 | monster
# Processing Record 46 of Set 15 | colares
# Processing Record 47 of Set 15 | vytegra
# Processing Record 48 of Set 15 | skeldon
# Processing Record 49 of Set 15 | mala vyska
# Processing Record 50 of Set 15 | alikovo
# Processing Record 1 of Set 16 | satipo
# Processing Record 2 of Set 16 | diu
# Processing Record 3 of Set 16 | unguia
# Processing Record 4 of Set 16 | kirando
# Processing Record 5 of Set 16 | agadez
# Processing Record 6 of Set 16 | chissamba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0           Pinar Del Rio  22.4175 -83.6981     72.90        91          35
# 1     Santiago Del Estero -27.7951 -64.2615     75.74        26           0
# 2                Felanitx  39.4696   3.1483     79.32        54          18
# 3               Jamestown  42.0970 -79.2353     44.19        66         100
# 4               Bealanana -14.5500  48.7333     76.51        39          57
# 5              Warrington  53.3925  -2.5802     60.80        72          40
# 6                    Chuy -33.6971 -53.4616     65.43        59          54
# 7                   Milas  37.3164  27.7839     79.95        26          40
# 8                Hermanus -34.4187  19.2345     72.81        67          77
# 9  Santa Cruz De La Palma  28.6835 -17.7642     78.13        69          20
#
#    Wind Speed Country       Description
# 0        4.97      CU  scattered clouds
# 1       13.67      AR         clear sky
# 2        9.24      ES        few clouds
# 3        5.75      US   overcast clouds
# 4       14.83      MG     broken clouds
# 5       14.97      GB  scattered clouds
# 6       14.92      UY     broken clouds
# 7        8.05      TR  scattered clouds
# 8       11.07      ZA     broken clouds
# 9       16.11      ES        few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                      City Country      Lat      Lng  Max Temp  Humidity  \
# 0           Pinar Del Rio      CU  22.4175 -83.6981     72.90        91
# 1     Santiago Del Estero      AR -27.7951 -64.2615     75.74        26
# 2                Felanitx      ES  39.4696   3.1483     79.32        54
# 3               Jamestown      US  42.0970 -79.2353     44.19        66
# 4               Bealanana      MG -14.5500  48.7333     76.51        39
# 5              Warrington      GB  53.3925  -2.5802     60.80        72
# 6                    Chuy      UY -33.6971 -53.4616     65.43        59
# 7                   Milas      TR  37.3164  27.7839     79.95        26
# 8                Hermanus      ZA -34.4187  19.2345     72.81        67
# 9  Santa Cruz De La Palma      ES  28.6835 -17.7642     78.13        69
#
#    Cloudiness  Wind Speed       Description
# 0          35        4.97  scattered clouds
# 1           0       13.67         clear sky
# 2          18        9.24        few clouds
# 3         100        5.75   overcast clouds
# 4          57       14.83     broken clouds
# 5          40       14.97  scattered clouds
# 6          54       14.92     broken clouds
# 7          40        8.05  scattered clouds
# 8          77       11.07     broken clouds
# 9          20       16.11        few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file, index_label = "City_ID")
